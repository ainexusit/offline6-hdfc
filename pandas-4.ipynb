# %%
import pandas as pd

# %%
df = pd.read_csv("Bank Customer Churn Prediction.csv")

# %%
df
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 0        15634602           619   France  Female   42       2       0.00
# 1        15647311           608    Spain  Female   41       1   83807.86
# 2        15619304           502   France  Female   42       8  159660.80
# 3        15701354           699   France  Female   39       1       0.00
# 4        15737888           850    Spain  Female   43       2  125510.82
# ...           ...           ...      ...     ...  ...     ...        ...
# 9995     15606229           771   France    Male   39       5       0.00
# 9996     15569892           516   France    Male   35      10   57369.61
# 9997     15584532           709   France  Female   36       7       0.00
# 9998     15682355           772  Germany    Male   42       3   75075.31
# 9999     15628319           792   France  Female   28       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  churn
# ...

# %%
df = pd.read_csv("amazon.csv")

# %%
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %%
def remove_rupee_symbols(element):
    return element.replace("₹",'')


df['clean_Col'] = df['discounted_price'].map(remove_rupee_symbols)

# %%
df[['discounted_price','clean_Col']]
# Out:
#      discounted_price clean_Col
# 0                ₹399       399
# 1                ₹199       199
# 2                ₹199       199
# 3                ₹329       329
# 4                ₹154       154
# ...               ...       ...
# 1460             ₹379       379
# 1461           ₹2,280     2,280
# 1462           ₹2,219     2,219
# 1463           ₹1,399     1,399
# 1464           ₹2,863     2,863
#
# [1465 rows x 2 columns]

# %%
df['clean1'] = df['discounted_price'].map(lambda x: x.replace('₹',''))

# %%
df[['clean1','discounted_price']]
# Out:
#      clean1 discounted_price
# 0       399             ₹399
# 1       199             ₹199
# 2       199             ₹199
# 3       329             ₹329
# 4       154             ₹154
# ...     ...              ...
# 1460    379             ₹379
# 1461  2,280           ₹2,280
# 1462  2,219           ₹2,219
# 1463  1,399           ₹1,399
# 1464  2,863           ₹2,863
#
# [1465 rows x 2 columns]

# %%
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %%
df = pd.DataFrame({"id":[1,2,3,4,5],
                   "name":['a','b','c','d','e'],
                   "sal":[56,87,23,98,60],
                   "gen":['M','f','m','sdafsdf','f']})

# %%
df
# Out:
#    id name  sal      gen
# 0   1    a   56        M
# 1   2    b   87        f
# 2   3    c   23        m
# 3   4    d   98  sdafsdf
# 4   5    e   60        f

# %%
df['gen_encode'] = df['gen'].map(lambda x: 1 if x.lower()=='m' else 0 if x.lower()=='f' else 'invalid')

# %%
df
# Out:
#    id name  sal      gen gen_encode
# 0   1    a   56        M          1
# 1   2    b   87        f          0
# 2   3    c   23        m          1
# 3   4    d   98  sdafsdf    invalid
# 4   5    e   60        f          0

# %%
gen_encode1 = {'m':1,"M":1,'f':0,'F':0}

# %%
df['test']= df['gen'].map(gen_encode1)

# %%
df
# Out:
#    id name  sal      gen gen_encode  test
# 0   1    a   56        M          1   1.0
# 1   2    b   87        f          0   0.0
# 2   3    c   23        m          1   1.0
# 3   4    d   98  sdafsdf    invalid   NaN
# 4   5    e   60        f          0   0.0

# %%
df1 = pd.DataFrame({"a":[1,2,3],
                    "b":[3,4,5],
                    "c":[7,8,9]})

# %%
df1
# Out:
#    a  b  c
# 0  1  3  7
# 1  2  4  8
# 2  3  5  9

# %%
def sqr(element):
    return element**2

# %%
df1.apply(sqr)
# Out:
#    a   b   c
# 0  1   9  49
# 1  4  16  64
# 2  9  25  81

# %%
df = pd.read_csv("emp (2).csv")

# %%
df
# Out:
#        id    name      sal     city
# 0   101.0  keshav  65646.0     pune
# 1   102.0    amit      NaN      NaN
# 2   103.0     NaN      NaN      NaN
# 3   104.0     NaN      NaN      NaN
# 4   105.0   rahul    545.0     pune
# 5   107.0  aniket   5353.0   mumbai
# 6   101.0  keshav  65646.0     pune
# 7   133.0    test      NaN      NaN
# 8   134.0     NaN      NaN      NaN
# 9     NaN     NaN      NaN      NaN
# 10    NaN     NaN      NaN      NaN
# 11    NaN     NaN      NaN      NaN
# 12  107.0  aniket   5353.0   mumbai
# 13  110.0   test1  53434.0  chennai
# 14  242.0     NaN      NaN      NaN

# %%
df.dropna()
# Out:
#        id    name      sal     city
# 0   101.0  keshav  65646.0     pune
# 4   105.0   rahul    545.0     pune
# 5   107.0  aniket   5353.0   mumbai
# 6   101.0  keshav  65646.0     pune
# 12  107.0  aniket   5353.0   mumbai
# 13  110.0   test1  53434.0  chennai

# %%
df.dropna(how='all')
# Out:
#        id    name      sal     city
# 0   101.0  keshav  65646.0     pune
# 1   102.0    amit      NaN      NaN
# 2   103.0     NaN      NaN      NaN
# 3   104.0     NaN      NaN      NaN
# 4   105.0   rahul    545.0     pune
# 5   107.0  aniket   5353.0   mumbai
# 6   101.0  keshav  65646.0     pune
# 7   133.0    test      NaN      NaN
# 8   134.0     NaN      NaN      NaN
# 12  107.0  aniket   5353.0   mumbai
# 13  110.0   test1  53434.0  chennai
# 14  242.0     NaN      NaN      NaN

# %%
df.dropna(subset=['id','name'])
# Out:
#        id    name      sal     city
# 0   101.0  keshav  65646.0     pune
# 1   102.0    amit      NaN      NaN
# 4   105.0   rahul    545.0     pune
# 5   107.0  aniket   5353.0   mumbai
# 6   101.0  keshav  65646.0     pune
# 7   133.0    test      NaN      NaN
# 12  107.0  aniket   5353.0   mumbai
# 13  110.0   test1  53434.0  chennai

# %%
df.dropna(thresh=2)
# Out:
#        id    name      sal     city
# 0   101.0  keshav  65646.0     pune
# 1   102.0    amit      NaN      NaN
# 4   105.0   rahul    545.0     pune
# 5   107.0  aniket   5353.0   mumbai
# 6   101.0  keshav  65646.0     pune
# 7   133.0    test      NaN      NaN
# 12  107.0  aniket   5353.0   mumbai
# 13  110.0   test1  53434.0  chennai

# %%
df
# Out:
#        id    name      sal     city
# 0   101.0  keshav  65646.0     pune
# 1   102.0    amit      NaN      NaN
# 2   103.0     NaN      NaN      NaN
# 3   104.0     NaN      NaN      NaN
# 4   105.0   rahul    545.0     pune
# 5   107.0  aniket   5353.0   mumbai
# 6   101.0  keshav  65646.0     pune
# 7   133.0    test      NaN      NaN
# 8   134.0     NaN      NaN      NaN
# 9     NaN     NaN      NaN      NaN
# 10    NaN     NaN      NaN      NaN
# 11    NaN     NaN      NaN      NaN
# 12  107.0  aniket   5353.0   mumbai
# 13  110.0   test1  53434.0  chennai
# 14  242.0     NaN      NaN      NaN

# %%
df.drop_duplicates(keep='last')
# Out:
#        id    name      sal     city
# 1   102.0    amit      NaN      NaN
# 2   103.0     NaN      NaN      NaN
# 3   104.0     NaN      NaN      NaN
# 4   105.0   rahul    545.0     pune
# 6   101.0  keshav  65646.0     pune
# 7   133.0    test      NaN      NaN
# 8   134.0     NaN      NaN      NaN
# 11    NaN     NaN      NaN      NaN
# 12  107.0  aniket   5353.0   mumbai
# 13  110.0   test1  53434.0  chennai
# 14  242.0     NaN      NaN      NaN

# %%
df['id'].value_counts()
# Out:
# id
# 101.0    2
# 107.0    2
# 102.0    1
# 103.0    1
# 104.0    1
# 105.0    1
# 133.0    1
# 134.0    1
# 110.0    1
# 242.0    1
# Name: count, dtype: int64

# %%
df
# Out:
#        id    name      sal     city
# 0   101.0  keshav  65646.0     pune
# 1   102.0    amit      NaN      NaN
# 2   103.0     NaN      NaN      NaN
# 3   104.0     NaN      NaN      NaN
# 4   105.0   rahul    545.0     pune
# 5   107.0  aniket   5353.0   mumbai
# 6   101.0  keshav  65646.0     pune
# 7   133.0    test      NaN      NaN
# 8   134.0     NaN      NaN      NaN
# 9     NaN     NaN      NaN      NaN
# 10    NaN     NaN      NaN      NaN
# 11    NaN     NaN      NaN      NaN
# 12  107.0  aniket   5353.0   mumbai
# 13  110.0   test1  53434.0  chennai
# 14  242.0     NaN      NaN      NaN

# %%
df
# Out:
#        id    name      sal     city
# 0   101.0  keshav  65646.0     pune
# 1   102.0    amit      NaN      NaN
# 2   103.0     NaN      NaN      NaN
# 3   104.0     NaN      NaN      NaN
# 4   105.0   rahul    545.0     pune
# 5   107.0  aniket   5353.0   mumbai
# 6   101.0  keshav  65646.0     pune
# 7   133.0    test      NaN      NaN
# 8   134.0     NaN      NaN      NaN
# 9     NaN     NaN      NaN      NaN
# 10    NaN     NaN      NaN      NaN
# 11    NaN     NaN      NaN      NaN
# 12  107.0  aniket   5353.0   mumbai
# 13  110.0   test1  53434.0  chennai
# 14  242.0     NaN      NaN      NaN

# %%
df.fillna(0)
# Out:
#        id    name      sal     city
# 0   101.0  keshav  65646.0     pune
# 1   102.0    amit      0.0        0
# 2   103.0       0      0.0        0
# 3   104.0       0      0.0        0
# 4   105.0   rahul    545.0     pune
# 5   107.0  aniket   5353.0   mumbai
# 6   101.0  keshav  65646.0     pune
# 7   133.0    test      0.0        0
# 8   134.0       0      0.0        0
# 9     0.0       0      0.0        0
# 10    0.0       0      0.0        0
# 11    0.0       0      0.0        0
# 12  107.0  aniket   5353.0   mumbai
# 13  110.0   test1  53434.0  chennai
# 14  242.0       0      0.0        0

# %%
df['sal_1']= df['sal'].fillna(0)

# %%
df
# Out:
#        id    name      sal     city    sal_1
# 0   101.0  keshav  65646.0     pune  65646.0
# 1   102.0    amit      NaN      NaN      0.0
# 2   103.0     NaN      NaN      NaN      0.0
# 3   104.0     NaN      NaN      NaN      0.0
# 4   105.0   rahul    545.0     pune    545.0
# 5   107.0  aniket   5353.0   mumbai   5353.0
# 6   101.0  keshav  65646.0     pune  65646.0
# 7   133.0    test      NaN      NaN      0.0
# 8   134.0     NaN      NaN      NaN      0.0
# 9     NaN     NaN      NaN      NaN      0.0
# 10    NaN     NaN      NaN      NaN      0.0
# 11    NaN     NaN      NaN      NaN      0.0
# 12  107.0  aniket   5353.0   mumbai   5353.0
# 13  110.0   test1  53434.0  chennai  53434.0
# 14  242.0     NaN      NaN      NaN      0.0

# %%
df['sal'].mean()
# Out:
# 32662.833333333332

# %%
df['sal'].median()
# Out:
# 29393.5

# %%
df['sal'].mode()
# Out:
# 0     5353.0
# 1    65646.0
# Name: sal, dtype: float64

# %%
df['sal_mean']= df['sal'].fillna(df['sal'].mean())

# %%
df['sal_1'].mean()
# Out:
# 13065.133333333333

# %%
df['sal'].mean()
# Out:
# 32662.833333333332

# %%
df
# Out:
#        id    name      sal     city    sal_1      sal_mean
# 0   101.0  keshav  65646.0     pune  65646.0  65646.000000
# 1   102.0    amit      NaN      NaN      0.0  32662.833333
# 2   103.0     NaN      NaN      NaN      0.0  32662.833333
# 3   104.0     NaN      NaN      NaN      0.0  32662.833333
# 4   105.0   rahul    545.0     pune    545.0    545.000000
# 5   107.0  aniket   5353.0   mumbai   5353.0   5353.000000
# 6   101.0  keshav  65646.0     pune  65646.0  65646.000000
# 7   133.0    test      NaN      NaN      0.0  32662.833333
# 8   134.0     NaN      NaN      NaN      0.0  32662.833333
# 9     NaN     NaN      NaN      NaN      0.0  32662.833333
# 10    NaN     NaN      NaN      NaN      0.0  32662.833333
# 11    NaN     NaN      NaN      NaN      0.0  32662.833333
# 12  107.0  aniket   5353.0   mumbai   5353.0   5353.000000
# 13  110.0   test1  53434.0  chennai  53434.0  53434.000000
# 14  242.0     NaN      NaN      NaN      0.0  32662.833333

# %%
df
# Out:
#        id    name      sal     city    sal_1      sal_mean
# 0   101.0  keshav  65646.0     pune  65646.0  65646.000000
# 1   102.0    amit      NaN      NaN      0.0  32662.833333
# 2   103.0     NaN      NaN      NaN      0.0  32662.833333
# 3   104.0     NaN      NaN      NaN      0.0  32662.833333
# 4   105.0   rahul    545.0     pune    545.0    545.000000
# 5   107.0  aniket   5353.0   mumbai   5353.0   5353.000000
# 6   101.0  keshav  65646.0     pune  65646.0  65646.000000
# 7   133.0    test      NaN      NaN      0.0  32662.833333
# 8   134.0     NaN      NaN      NaN      0.0  32662.833333
# 9     NaN     NaN      NaN      NaN      0.0  32662.833333
# 10    NaN     NaN      NaN      NaN      0.0  32662.833333
# 11    NaN     NaN      NaN      NaN      0.0  32662.833333
# 12  107.0  aniket   5353.0   mumbai   5353.0   5353.000000
# 13  110.0   test1  53434.0  chennai  53434.0  53434.000000
# 14  242.0     NaN      NaN      NaN      0.0  32662.833333

# %%
df['city_ffill'] = df['city'].fillna(method='ffill')
# Out:
# C:\Users\AINEXUS IT INSTITUTE\AppData\Local\Temp\ipykernel_6172\2315224074.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['city_ffill'] = df['city'].fillna(method='ffill')

# %%
df['city_bfill'] = df['city'].fillna(method='bfill')
# Out:
# C:\Users\AINEXUS IT INSTITUTE\AppData\Local\Temp\ipykernel_6172\2407679246.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['city_bfill'] = df['city'].fillna(method='bfill')

# %%
df['city_bfill'].fillna('Pune')
# Out:
# 0        pune
# 1        pune
# 2        pune
# 3        pune
# 4        pune
# 5      mumbai
# 6        pune
# 7      mumbai
# 8      mumbai
# 9      mumbai
# 10     mumbai
# 11     mumbai
# 12     mumbai
# 13    chennai
# 14       Pune
# Name: city_bfill, dtype: object

# %%
df
# Out:
#        id    name      sal     city    sal_1      sal_mean city_ffill  \
# 0   101.0  keshav  65646.0     pune  65646.0  65646.000000       pune
# 1   102.0    amit      NaN      NaN      0.0  32662.833333       pune
# 2   103.0     NaN      NaN      NaN      0.0  32662.833333       pune
# 3   104.0     NaN      NaN      NaN      0.0  32662.833333       pune
# 4   105.0   rahul    545.0     pune    545.0    545.000000       pune
# 5   107.0  aniket   5353.0   mumbai   5353.0   5353.000000     mumbai
# 6   101.0  keshav  65646.0     pune  65646.0  65646.000000       pune
# 7   133.0    test      NaN      NaN      0.0  32662.833333       pune
# 8   134.0     NaN      NaN      NaN      0.0  32662.833333       pune
# 9     NaN     NaN      NaN      NaN      0.0  32662.833333       pune
# 10    NaN     NaN      NaN      NaN      0.0  32662.833333       pune
# 11    NaN     NaN      NaN      NaN      0.0  32662.833333       pune
# ...
